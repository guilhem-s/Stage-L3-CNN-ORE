# %%
import tensorflow as tf
import keras
import os
import cv2
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from skimage.metrics import structural_similarity as ssim
from keras.models import load_model, Model
from scipy.stats import gaussian_kde
from keras import Input
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from keras.layers import Conv2D, MaxPooling2D, Resizing, UpSampling2D, Dense, BatchNormalization, Add, Flatten, Reshape, add
from keras.models import Sequential
from keras.optimizers import SGD, Adam

# %%
def loss_ssim(y_true, y_pred):
    # Calculer le data_range
    data_range = tf.reduce_max(y_true) - tf.reduce_min(y_true)
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=data_range))

# %%
def residual_block_Gui(x, filters, kernel_size=3, is_encoder=True):
    shortcut = x
    # Convolutions
    x = Conv2D(filters, kernel_size, activation='relu', padding='same', use_bias=False)(x)
    x = MaxPooling2D((2,2), padding='same')(x) if is_encoder else UpSampling2D(2)(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters, kernel_size, strides=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(filters, kernel_size, activation='relu', padding='same', use_bias=False)(shortcut)
    shortcut = MaxPooling2D((2,2), padding='same')(shortcut) if is_encoder else UpSampling2D(2)(shortcut)
    shortcut = BatchNormalization()(shortcut)

    x = add([x, shortcut])
    return x

# %%
def generator_to_array(generator):
    # Initialiser une liste pour stocker les échantillons
    num_samples = len(generator)
    samples = []
    # Itérer sur le générateur pour obtenir les échantillons
    for i in range(num_samples):
        batch = generator.next()
        for image in batch[0]:
            samples.append(image)  # Ajouter uniquement les données (ignorer les étiquettes)
    return np.array(samples)

def mean_cosinus_similarity(v1, v2):
    cosinus_similarity = 0
    nb_individus = v1.shape[0]
    for i in range(nb_individus):
        cosinus_similarity += np.dot(v1[i], v2[i]) / (np.linalg.norm(v1[i]) * np.linalg.norm(v2[i]))
    return cosinus_similarity/nb_individus

def calculate_mean_dispersion(latent_representations):
    centroid = np.mean(latent_representations, axis=0)
    distance_squared = np.sum((latent_representations - centroid)**2, axis = 1)
    return np.mean(distance_squared)

def comparaison_visages(asian, asian_predict, white, white_predict, ethnie):

    plt.figure(figsize=(15, 6))

    # Affichage des images du premier trainset
    plt.subplot(2, 5, (1, 5))
    plt.axis("off")
    plt.title('Caucasiens')
    for i in range(5):
        plt.subplot(2, 5, i + 1)
        plt.imshow(white[i], cmap='gray')
        plt.axis('off')
        plt.subplot(2, 5, i + 6)
        plt.imshow(white_predict[i], cmap='gray')
        plt.axis('off')

    # Titre global
    plt.suptitle(f'Comparaison des images d entrées et de sorties caucasiennes d espace latent {ethnie}')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(15, 6))

    # Affichage des images du premier trainset
    plt.subplot(2, 5, (1, 5))
    plt.axis("off")
    plt.title('Asiatiques')
    for i in range(5):
        plt.subplot(2, 5, i + 1)
        plt.imshow(asian[i], cmap='gray')
        plt.axis('off')
        plt.subplot(2, 5, i + 6)
        plt.imshow(asian_predict[i], cmap='gray')
        plt.axis('off')

    # Titre global
    plt.suptitle('Comparaison des images d entrées et de sorties asiatiques')
    plt.tight_layout()
    plt.show()

def pca(latent_asian, latent_white, ethnie):
    pca = PCA(n_components=2)
    latent_pca_white = pca.fit_transform(latent_white)
    latent_pca_asian = pca.fit_transform(latent_asian)
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(latent_pca_white[:, 0], latent_pca_white[:, 1], color='r', alpha=0.5, label='white_predict')
    scatter_b = plt.scatter(latent_pca_asian[:, 0], latent_pca_asian[:, 1], color='b', alpha=0.5, label='asian_predict')
    plt.legend(handles=[scatter, scatter_b])
    plt.title(f'Projection ACP de l espace latent {ethnie}')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.show()

    return np.concatenate([latent_pca_white, latent_pca_asian], axis=0)


def cosinus_similarity(asian_flatten, asian_predict_flatten, white_flatten, white_predict_flatten):
    asian_cs = mean_cosinus_similarity(asian_flatten, asian_predict_flatten)
    white_cs = mean_cosinus_similarity(white_flatten, white_predict_flatten)
    print(f"Moyenne des similarités cosinus pour les individus caucasiens : {white_cs}")
    print(f"Moyenne des similarités cosinus pour les individus asiatiques : {asian_cs}")
    
def comparaison_dispersion(latent_asian, latent_white):
    asian_mean_dispersion = calculate_mean_dispersion(latent_asian)
    white_mean_dispersion = calculate_mean_dispersion(latent_white)
    print(f"Moyenne des dispersions des espaces latents pour les individus caucasiens : {white_mean_dispersion}")
    print(f"Moyenne des dispersions des espaces latents pour les individus asiatiques : {asian_mean_dispersion}")

def coef_bhattacharyya(latent_asian, latent_white):
    normalize_a = tf.nn.l2_normalize(np.mean(latent_asian, axis=0),axis=0)        
    normalize_b = tf.nn.l2_normalize(np.mean(latent_white, axis=0),axis=0)
    return tf.reduce_sum(tf.multiply(normalize_a,normalize_b))

def ssim_mean(ytrue, ypred, length):    
    res = 0
    for i in range(length):
        res+=ssim(ytrue[i], ypred[i], data_range=ytrue[i].max() - ytrue[i].min(), multichannel=False)
    
    return res/length

def structure_ssim(ytrue, ypred):
    return ssim(ytrue, ypred, data_range=ytrue.max() - ytrue.min(), multichannel=False)

# %%
def create_autoencodeur(input_shape=(150, 150, 1), input_latent=512):

    np.random.seed(42)
    model=Sequential()

    model.add(Conv2D(64, (3,3),activation='relu',padding='same', input_shape=(input_shape)))
    model.add(MaxPooling2D((2,2), padding='same'))
    model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(MaxPooling2D((2,2), padding='same'))
    model.add(Conv2D(16, (3,3),activation='relu',padding='same'))
    model.add(MaxPooling2D((2,2), padding='same'))
    
    model.add(Dense(input_latent, activation='relu'))

    model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(UpSampling2D((2,2)))

    model.add(Conv2D(1, (3,3), activation='relu', padding='same'))

    model.add(Resizing(height=input_shape[0], width=input_shape[1], name='recon_image'))
    model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])

    model.summary()
    return model
model = create_autoencodeur(input_shape=(300, 300, 1), input_latent=2048)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 300, 300, 64)      640
#
#  max_pooling2d_9 (MaxPooling  (None, 150, 150, 64)     0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 150, 150, 32)      18464
#
#  max_pooling2d_10 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 75, 75, 16)        4624
#
#  max_pooling2d_11 (MaxPoolin  (None, 38, 38, 16)       0
#  g2D)
#
#  dense (Dense)               (None, 38, 38, 2048)      34816
#
#  conv2d_21 (Conv2D)          (None, 38, 38, 16)        294928
#
#  up_sampling2d_9 (UpSampling  (None, 76, 76, 16)       0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 76, 76, 32)        4640
#
#  up_sampling2d_10 (UpSamplin  (None, 152, 152, 32)     0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 152, 152, 64)      18496
#
#  up_sampling2d_11 (UpSamplin  (None, 304, 304, 64)     0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 304, 304, 1)       577
#
#  recon_image (Resizing)      (None, 300, 300, 1)       0
#
# =================================================================
# Total params: 377,185
# Trainable params: 377,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=trainset_white, epochs=1000, validation_data=testset_white)
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 7s 552ms/step - loss: 0.1076 - accuracy: 0.2057 - val_loss: 0.0823 - val_accuracy: 0.1032
# Epoch 2/1000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0431 - accuracy: 0.2087 - val_loss: 0.0223 - val_accuracy: 0.1015
# Epoch 3/1000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0137 - accuracy: 0.2098 - val_loss: 0.0112 - val_accuracy: 0.1030
# Epoch 4/1000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0090 - accuracy: 0.2101 - val_loss: 0.0069 - val_accuracy: 0.1031
# Epoch 5/1000
# 9/9 [==============================] - 4s 423ms/step - loss: 0.0066 - accuracy: 0.2102 - val_loss: 0.0056 - val_accuracy: 0.1031
# Epoch 6/1000
# 9/9 [==============================] - 4s 422ms/step - loss: 0.0056 - accuracy: 0.2101 - val_loss: 0.0050 - val_accuracy: 0.1031
# Epoch 7/1000
# 9/9 [==============================] - 4s 425ms/step - loss: 0.0049 - accuracy: 0.2101 - val_loss: 0.0044 - val_accuracy: 0.1031
# Epoch 8/1000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0045 - accuracy: 0.2101 - val_loss: 0.0040 - val_accuracy: 0.1031
# Epoch 9/1000
# 9/9 [==============================] - 3s 357ms/step - loss: 0.0042 - accuracy: 0.2101 - val_loss: 0.0039 - val_accuracy: 0.1032
# Epoch 10/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0038 - accuracy: 0.2101 - val_loss: 0.0034 - val_accuracy: 0.1031
# Epoch 11/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0038 - accuracy: 0.2101 - val_loss: 0.0034 - val_accuracy: 0.1032
# Epoch 12/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0034 - accuracy: 0.2102 - val_loss: 0.0033 - val_accuracy: 0.1032
# Epoch 13/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0033 - accuracy: 0.2101 - val_loss: 0.0029 - val_accuracy: 0.1032
# Epoch 14/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0030 - accuracy: 0.2102 - val_loss: 0.0027 - val_accuracy: 0.1032
# Epoch 15/1000
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0029 - accuracy: 0.2102 - val_loss: 0.0026 - val_accuracy: 0.1032
# Epoch 16/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0027 - accuracy: 0.2102 - val_loss: 0.0023 - val_accuracy: 0.1033
# Epoch 17/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0025 - accuracy: 0.2102 - val_loss: 0.0021 - val_accuracy: 0.1033
# Epoch 18/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0023 - accuracy: 0.2102 - val_loss: 0.0022 - val_accuracy: 0.1033
# Epoch 19/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0022 - accuracy: 0.2102 - val_loss: 0.0020 - val_accuracy: 0.1033
# Epoch 20/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0021 - accuracy: 0.2102 - val_loss: 0.0019 - val_accuracy: 0.1033
# Epoch 21/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.
1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0017 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 253/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0016 - accuracy: 0.2102 - val_loss: 0.0015 - val_accuracy: 0.1033
# Epoch 254/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 255/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 256/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 257/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 258/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 259/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 260/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 261/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 262/1000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 263/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 264/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 265/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 266/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 267/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 268/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 269/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 270/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 271/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 272/1000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 273/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 274/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 275/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 276/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 277/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 278/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 279/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0015 - val_accuracy: 0.1033
# Epoch 280/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0015 - accuracy: 0.2102 - val_loss: 0.0018 - val_accuracy: 0.1033
# Epoch 281/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0015 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 282/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0014 - accuracy: 0.2102 - val_loss: 0.0013 - val_accuracy: 0.1033
# Epoch 283/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 284/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0013 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 285/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 286/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 287/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 288/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 289/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 290/1000
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 291/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 292/1000
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 293/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 294/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0011 - val_accuracy: 0.1033
# Epoch 295/1000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0012 - accuracy: 0.2102 - val_loss: 0.0012 - val_accuracy: 0.1033
# Epoch 296/1000
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0012 - accuracy: 0.2564
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model.fit(x=trainset_white, epochs=1000, validation_data=testset_white)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\guilh\anaconda3\envs\envguilhem\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, BatchNormalization, LeakyReLU, Dropout, Conv2DTranspose
from keras.losses import MeanAbsoluteError

def create_autoencodeur(input_shape=(150, 150, 1)):
    input_img = Input(shape=input_shape)

    # Encodeur
    x = Conv2D(64, (3, 3), activation='linear', padding='same')(input_img)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    
    x = Conv2D(32, (3, 3), activation='linear', padding='same')(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    
    x = Conv2D(16, (3, 3), activation='linear', padding='same')(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((4, 4), padding='same')(x)

    # Espace latent
    shape_before_flattening = x.shape[1:]
    print(shape_before_flattening)
    latent_space = Flatten()(x)
    print(latent_space.shape)

    # Décodeur
    x = Reshape(shape_before_flattening)(latent_space)
    x = Conv2DTranspose(16, (3, 3), activation='linear', padding='same')(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((4, 4))(x)
    
    x = Conv2DTranspose(32, (3, 3), activation='linear', padding='same')(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    
    x = Conv2DTranspose(64, (3, 3), activation='linear', padding='same')(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    
    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    # Modèle autoencodeur
    autoencoder = Model(input_img, decoded)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss=MeanAbsoluteError(), metrics=['accuracy'])
    
    # Ajout d'une couche de sortie pour l'espace latent
    encoder_output = Model(inputs=input_img, outputs=latent_space)
    
    # Afficher le résumé du modèle
    autoencoder.summary()
    encoder_output.summary()
    
    return autoencoder, encoder_output
autoencoder, encoder = create_autoencodeur()
# Out:
# (10, 10, 16)
# (None, 1600)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 1)]     0
#
#  conv2d (Conv2D)             (None, 150, 150, 64)      640
#
#  leaky_re_lu (LeakyReLU)     (None, 150, 150, 64)      0
#
#  batch_normalization (BatchN  (None, 150, 150, 64)     256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        18464
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 75, 75, 32)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 16)        4624
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 38, 38, 16)        0
#
#  batch_normalization_2 (Batc  (None, 38, 38, 16)       64
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  reshape (Reshape)           (None, 10, 10, 16)        0
#
#  conv2d_transpose (Conv2DTra  (None, 10, 10, 16)       2320
#  nspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 10, 10, 16)        0
#
#  batch_normalization_3 (Batc  (None, 10, 10, 16)       64
#  hNormalization)
#
#  up_sampling2d (UpSampling2D  (None, 40, 40, 16)       0
#  )
#
#  conv2d_transpose_1 (Conv2DT  (None, 40, 40, 32)       4640
#  ranspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 40, 40, 32)        0
#
#  batch_normalization_4 (Batc  (None, 40, 40, 32)       128
#  hNormalization)
#
#  up_sampling2d_1 (UpSampling  (None, 80, 80, 32)       0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 80, 80, 64)       18496
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 80, 80, 64)        0
#
#  batch_normalization_5 (Batc  (None, 80, 80, 64)       256
#  hNormalization)
#
#  up_sampling2d_2 (UpSampling  (None, 160, 160, 64)     0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 160, 160, 1)       577
#
# =================================================================
# Total params: 50,657
# Trainable params: 50,209
# Non-trainable params: 448
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 1)]     0
#
#  conv2d (Conv2D)             (None, 150, 150, 64)      640
#
#  leaky_re_lu (LeakyReLU)     (None, 150, 150, 64)      0
#
#  batch_normalization (BatchN  (None, 150, 150, 64)     256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        18464
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 75, 75, 32)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 16)        4624
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 38, 38, 16)        0
#
#  batch_normalization_2 (Batc  (None, 38, 38, 16)       64
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
# =================================================================
# Total params: 24,176
# Trainable params: 23,952
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, LeakyReLU, Resizing
from keras.models import Model
from keras.losses import MeanAbsoluteError
from keras.optimizers import Adam

def create_autoencoder(input_shape=(150, 150, 1), input_latent=512):
    input_img = Input(shape=input_shape)
    x = input_img
    filters = [16, 32, 64]
    # Encoder
    for i, filter in enumerate(filters):
        x = Conv2D(filter, (3, 3), activation='linear', padding='same')(x)
        x = LeakyReLU(alpha=0.1)(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D((2, 2), padding='same')(x)
        print(f'After {i+1} MaxPooling2D: {x.shape}')

    # Espace latent
    x = Conv2D(10, (3, 3), activation='relu', padding='same', name='latent_space')(x)
    print(f'After latent_space: {x.shape}')
    """ # Espace latent
    shape_before_flattening = x.shape[1:]
    x = Flatten()(x)
    latent_space = Dense(input_latent, activation='relu')(x)
    latent_space_norm = BatchNormalization()(latent_space)
    latent_space = Dense(np.prod(shape_before_flattening))(latent_space)
    print(x.shape)
    x = Reshape(shape_before_flattening)(latent_space)
    print(x.shape) """

    # Décodeur
    for i, filter in enumerate(reversed(filters)):
        x = Conv2D(filter, (3, 3), activation='linear', padding='same')(x)
        x = LeakyReLU(alpha=0.1)(x)
        x = BatchNormalization()(x)
        x = UpSampling2D((2, 2))(x)
        print(f'After {i+1} UpSampling2D: {x.shape}')
    
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    print(f'Decoded shape before resizing: {x.shape}')    
    # Resize to match input shape
    decoded = Resizing(height=input_shape[0], width=input_shape[1], name='final_output')(x)
    print(f'Decoded shape after resizing: {decoded.shape}')

    # Autoencoder model
    autoencoder = Model(input_img, decoded)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss=MeanAbsoluteError(), metrics=['accuracy'])
    
    # Display the model summary
    autoencoder.summary()
    
    return autoencoder

autoencoder = create_autoencoder(input_shape=(300, 300, 1), input_latent=2048)
# Out:
# After 1 MaxPooling2D: (None, 150, 150, 16)
# After 2 MaxPooling2D: (None, 75, 75, 32)
# After 3 MaxPooling2D: (None, 38, 38, 64)
# After latent_space: (None, 38, 38, 10)
# After 1 UpSampling2D: (None, 76, 76, 64)
# After 2 UpSampling2D: (None, 152, 152, 32)
# After 3 UpSampling2D: (None, 304, 304, 16)
# Decoded shape before resizing: (None, 304, 304, 1)
# Decoded shape after resizing: (None, 300, 300, 1)
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 1)]     0
#
#  conv2d_4 (Conv2D)           (None, 300, 300, 16)      160
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 300, 300, 16)      0
#
#  batch_normalization_6 (Batc  (None, 300, 300, 16)     64
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 150, 150, 16)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 150, 150, 32)      4640
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 150, 150, 32)      0
#
#  batch_normalization_7 (Batc  (None, 150, 150, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 75, 75, 64)        18496
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 75, 75, 64)        0
#
#  batch_normalization_8 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  latent_space (Conv2D)       (None, 38, 38, 10)        5770
#
#  conv2d_7 (Conv2D)           (None, 38, 38, 64)        5824
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 38, 38, 64)        0
#
#  batch_normalization_9 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  up_sampling2d_3 (UpSampling  (None, 76, 76, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 76, 76, 32)        18464
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 76, 76, 32)        0
#
#  batch_normalization_10 (Bat  (None, 76, 76, 32)       128
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 152, 152, 32)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 152, 152, 16)      4624
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 152, 152, 16)      0
#
#  batch_normalization_11 (Bat  (None, 152, 152, 16)     64
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 304, 304, 16)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 304, 304, 1)       145
#
#  final_output (Resizing)     (None, 300, 300, 1)       0
#
# =================================================================
# Total params: 59,019
# Trainable params: 58,571
# Non-trainable params: 448
# _________________________________________________________________

# %%
autoencoder.fit(x=trainset_asian, epochs=100, validation_data=testset_asian)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 52ms/step - loss: 0.0169 - accuracy: 0.5382 - val_loss: 0.3274 - val_accuracy: 0.2912
# Epoch 2/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0176 - accuracy: 0.5382 - val_loss: 0.0228 - val_accuracy: 0.6099
# Epoch 3/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0169 - accuracy: 0.5382 - val_loss: 0.0354 - val_accuracy: 0.6099
# Epoch 4/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0199 - accuracy: 0.5382 - val_loss: 0.0453 - val_accuracy: 0.6099
# Epoch 5/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0167 - accuracy: 0.5382 - val_loss: 0.0227 - val_accuracy: 0.6099
# Epoch 6/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0190 - accuracy: 0.5382 - val_loss: 0.0289 - val_accuracy: 0.6095
# Epoch 7/100
# 9/9 [==============================] - 0s 49ms/step - loss: 0.0166 - accuracy: 0.5382 - val_loss: 0.0410 - val_accuracy: 0.6093
# Epoch 8/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0173 - accuracy: 0.5382 - val_loss: 0.0621 - val_accuracy: 0.6093
# Epoch 9/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0164 - accuracy: 0.5382 - val_loss: 0.0512 - val_accuracy: 0.6095
# Epoch 10/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0146 - accuracy: 0.5382 - val_loss: 0.0358 - val_accuracy: 0.6098
# Epoch 11/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0144 - accuracy: 0.5382 - val_loss: 0.0204 - val_accuracy: 0.6099
# Epoch 12/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0145 - accuracy: 0.5382 - val_loss: 0.0154 - val_accuracy: 0.6099
# Epoch 13/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0165 - accuracy: 0.5382 - val_loss: 0.0276 - val_accuracy: 0.6099
# Epoch 14/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0138 - accuracy: 0.5382 - val_loss: 0.0185 - val_accuracy: 0.6099
# Epoch 15/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0147 - accuracy: 0.5382 - val_loss: 0.0300 - val_accuracy: 0.6099
# Epoch 16/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0153 - accuracy: 0.5382 - val_loss: 0.0306 - val_accuracy: 0.6099
# Epoch 17/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0158 - accuracy: 0.5382 - val_loss: 0.0192 - val_accuracy: 0.6099
# Epoch 18/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0158 - accuracy: 0.5382 - val_loss: 0.0218 - val_accuracy: 0.6099
# Epoch 19/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0150 - accuracy: 0.5382 - val_loss: 0.0159 - val_accuracy: 0.6099
# Epoch 20/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0139 - accuracy: 0.5382 - val_loss: 0.0133 - val_accuracy: 0.6099
# Epoch 21/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0144 - accuracy: 0.5382 - val_loss: 0.0149 - val_accuracy: 0.6099
# Epoch 22/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0151 - accuracy: 0.5382 - val_loss: 0.0844 - val_accuracy: 0.6060
# Epoch 23/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0192 - accuracy: 0.5382 - val_loss: 0.0356 - val_accuracy: 0.6099
# Epoch 24/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0174 - accuracy: 0.5382 - val_loss: 0.0212 - val_accuracy: 0.6099
# Epoch 25/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.
100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0146 - accuracy: 0.5382 - val_loss: 0.0574 - val_accuracy: 0.6099
# Epoch 85/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0150 - accuracy: 0.5382 - val_loss: 0.0143 - val_accuracy: 0.6099
# Epoch 86/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0135 - accuracy: 0.5382 - val_loss: 0.0115 - val_accuracy: 0.6099
# Epoch 87/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0142 - accuracy: 0.5382 - val_loss: 0.0109 - val_accuracy: 0.6099
# Epoch 88/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0120 - accuracy: 0.5382 - val_loss: 0.0123 - val_accuracy: 0.6099
# Epoch 89/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0134 - accuracy: 0.5382 - val_loss: 0.0117 - val_accuracy: 0.6099
# Epoch 90/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0122 - accuracy: 0.5382 - val_loss: 0.0213 - val_accuracy: 0.6099
# Epoch 91/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0120 - accuracy: 0.5382 - val_loss: 0.0133 - val_accuracy: 0.6099
# Epoch 92/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0147 - accuracy: 0.5382 - val_loss: 0.0119 - val_accuracy: 0.6099
# Epoch 93/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0140 - accuracy: 0.5382 - val_loss: 0.0997 - val_accuracy: 0.6040
# Epoch 94/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0152 - accuracy: 0.5382 - val_loss: 0.0781 - val_accuracy: 0.6082
# Epoch 95/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0169 - accuracy: 0.5382 - val_loss: 0.0429 - val_accuracy: 0.6099
# Epoch 96/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0137 - accuracy: 0.5382 - val_loss: 0.0162 - val_accuracy: 0.6099
# Epoch 97/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0677 - accuracy: 0.5232 - val_loss: 0.0878 - val_accuracy: 0.6085
# Epoch 98/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0301 - accuracy: 0.5382 - val_loss: 0.0903 - val_accuracy: 0.6078
# Epoch 99/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0242 - accuracy: 0.5380 - val_loss: 0.1101 - val_accuracy: 0.5955
# Epoch 100/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0222 - accuracy: 0.5381 - val_loss: 0.1195 - val_accuracy: 0.5886

# %% [markdown]
# 9/9 [==============================] - 3s 386ms/step - loss: 0.0042 - accuracy: 0.2101 - val_loss: 0.0039 - val_accuracy: 0.1032

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
trainset_white = train_datagen.flow_from_directory(
    '../../Datasets/STIM_NB_LumNorm/Train',
    classes=['Caucasiens'],
    target_size=(300, 300), 
    batch_size=6, 
    class_mode='input',
    color_mode='grayscale')
testset_white = train_datagen.flow_from_directory(
    '../../Datasets/STIM_NB_LumNorm/Test',
    classes=['Caucasiens'],
    target_size=(300, 300), 
    batch_size=6, 
    class_mode='input',
    color_mode='grayscale')
trainset_asian = train_datagen.flow_from_directory(
    '../../Datasets/STIM_NB_LumNorm/Train',
    classes=['Asiatiques'],
    target_size=(300, 300),
    batch_size=6,
    class_mode='input',
    color_mode='grayscale')
testset_asian = train_datagen.flow_from_directory(
    '../../Datasets/STIM_NB_LumNorm/Test',
    classes=['Asiatiques'],
    target_size=(300, 300),
    batch_size=6,
    class_mode='input',
    color_mode='grayscale')
trainset_mixed = train_datagen.flow_from_directory(
    '../../Datasets/STIM_NB_LumNorm/',
    classes=['Mixtes'],
    target_size=(300, 300), 
    batch_size=10, 
    class_mode='input',
    color_mode='grayscale')
# Out:
# Found 50 images belonging to 1 classes.
# Found 6 images belonging to 1 classes.
# Found 50 images belonging to 1 classes.
# Found 6 images belonging to 1 classes.
# Found 112 images belonging to 1 classes.

# %% [markdown]
# ### Entrainement réseau & Récupération de la couche latente

# %%
callback = EarlyStopping(monitor='loss', patience=3)

# %%
auto1.fit(x=trainset_white, epochs=1000, validation_data=testset_white, verbose=1)

# %%
pred = model.predict(testset_white)
# Out:
# 1/1 [==============================] - 0s 423ms/step

# %%
n = 6  # Number of images to display
plt.figure(figsize=(20, 4))

for i in range(n):
    # Afficher l'image originale
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(white[i].reshape(300, 300), cmap='gray')
    plt.title("Original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(pred[i].reshape(300, 300), cmap='gray')
    plt.title("Reconstruction")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
get_latent = keras.Model(inputs=model.input, outputs=model.get_layer('dense').output)

# %%
latent_asian = get_latent.predict(trainset_asian, verbose=0)
latent_white = get_latent.predict(trainset_white, verbose=0)
latent_asian = latent_asian.reshape(50, -1)
latent_white = latent_white.reshape(50, -1)

asian_predict = autoencoder.predict(trainset_asian, verbose=0).reshape(50,300,300)
white_predict = autoencoder.predict(trainset_white, verbose=0).reshape(50,300,300)
asian = generator_to_array(trainset_asian).reshape(50,300,300)
white = generator_to_array(trainset_white).reshape(50,300,300)

asian_predict_flatten = asian_predict.reshape(50, -1)
white_predict_flatten = white_predict.reshape(50, -1)
asian_flatten = asian.reshape(50, -1)
white_flatten = white.reshape(50, -1)

test_asian = generator_to_array(testset_asian).reshape(6, 300, 300)
test_asian_predict = autoencoder.predict(testset_asian).reshape(6, 300, 300)
test_white = generator_to_array(testset_white).reshape(6, 300, 300)
test_white_predict = autoencoder.predict(testset_white).reshape(6, 300, 300)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
def mean_bhatta(latent_asian, latent_white):
    res = 0
    for i in range(len(latent_asian)):
        res += bhatta_coeff(latent_asian[i], latent_white[i])
        return res/len(latent_asian)

# %%
def mean_bhatta_coeff(p, q):
    bhatta = 0
    if p.ndim == 1:
        for i in range(p.shape[0]):
            bhatta += np.sqrt((p[i] * q[i]))
        return bhatta
    else:
        for i in range(p.shape[0]):
            for j in range(p.shape[1]):
                bhatta += np.sqrt((p[i, j] * q[i, j]))
    return bhatta/p.shape[0]

# %%
mean_bhatta_coeff(latent_asian_distrib, latent_white_distrib)

# %%
comparaison_visages(asian, asian_predict, white, white_predict, "white")
latent_pca = pca(latent_asian, latent_white, "white")
cosinus_similarity(asian_flatten, asian_predict_flatten, white_flatten, white_predict_flatten)
print(f"La similarité structurelle pour les caucasiens est de : {ssim_mean(white, white_predict, 50)}")
print(f"La similarité structurelle pour les asiatiques est de : {ssim_mean(asian, asian_predict, 50)}")
comparaison_dispersion(latent_asian, latent_white)
# Out:
# Moyenne des similarités cosinus pour les individus caucasiens : 0.9368249356746674
# Moyenne des similarités cosinus pour les individus asiatiques : 0.9465834057331085
# La similarité structurelle pour les caucasiens est de : 0.47455148004226017
# La similarité structurelle pour les asiatiques est de : 0.7221602839265688
# Moyenne des dispersions des espaces latents pour les individus caucasiens : 10.325517654418945
# Moyenne des dispersions des espaces latents pour les individus asiatiques : 6.145340442657471
